# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# - Задание 1
#
# Дан объект в 2D пространстве
#
# При помощи линейных отображений:
#
# Уменьшить объект в два раза
#
# Повернуть на 130 градусов
#
# Отразить объект относительно прямой y = x (поможет матрица [[0, 1, 0], [1, 0, 0], [0, 0, 1]])

# %%
A = [
[-100, -100, 1],
[-100, 100, 1],
[100, 100, 1],
[0, 0, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
B = [[0.5, 0, 0], [0, 0.5, 0], [0, 0, 0.5]]
B = np.array(B)

# %%
res = B @ A.transpose()
result = res.transpose()

# %%
A = np.array(result)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
x = 13 * math.pi / 18
x
# Out:
# 2.2689280275926285

# %%
B2=[[math.cos(-13 * math.pi / 18), math.sin(13 * math.pi / 18),
      math.sin(13 * math.pi / 18)], [math.sin(-13 * math.pi / 18),
        math.cos(-13 * math.pi/18), math.sin(13 * math.pi / 18)], 
     [math.sin(-13 * math.pi / 18), math.sin(-13*math.pi / 18),math.cos(-13 * math.pi / 18)]]

# %%
B2f = np.array(B2)
res_2 = B2f @ A.transpose()
result2 = res_2.transpose()

# %%
A = np.array(result2)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
B_ = [[0, 1, 0], [1, 0, 0], [0, 0, 1]]
B_ = np.array(B)

# %%
res_ = B_ @ A.transpose()
result_ = res_.transpose()

# %%
A = np.array(result_)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# - Задание 2
#
# Найдите спектральное разложение матрицы

# %%
m = np.array([[1, 2], [2, 3]]) 
m
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
np.linalg.eig(m)
# Out:
# (array([-0.23606798,  4.23606798]),
#  array([[-0.85065081, -0.52573111],
#         [ 0.52573111, -0.85065081]]))

# %%
S = np.array([[-0.85065081, -0.52573111],[ 0.52573111, -0.85065081]])
S
# Out:
# array([[-0.85065081, -0.52573111],
#        [ 0.52573111, -0.85065081]])

# %%
St = S.transpose()
St
# Out:
# array([[-0.85065081,  0.52573111],
#        [-0.52573111, -0.85065081]])

# %%
D = np.array([[-0.23606798, 0],[0, 4.23606798]])

# %%
 S @ D @ St
# Out:
# array([[0.99999999, 2.        ],
#        [2.        , 3.00000001]])
