# %%
import numpy as np
from sympy import *
import math
import matplotlib.pyplot as plt
from sympy.plotting import plot

# %% [markdown]
# - Задание 1
#
#
# Посчитайте значение первой и второй производной функции:

# %%
x = Symbol('x')
f = Function('f')

# %%
def f(x):
    return  x**5 + 4*sin(2*x) + cos(3*x + 2)

f(1)
# Out:
# cos(5) + 1 + 4*sin(2)

# %%
first = diff(f(x))
first
# Out:
# 5*x**4 - 3*sin(3*x + 2) + 8*cos(2*x)

# %%
second = diff(first)
second
# Out:
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 2)

# %% [markdown]
#  - Задание 2
#
#
# Постройте график первой и второй производной функции:

# %%
y = sin(x)
f = y**5 * (2 * x + 1)
y_first = diff(f)
y_second = diff(y_first)

# %%
plot(y_first, y_second, ('x', -5, 5, 100))
